# %% [markdown]
# # 정적 웹크롤링
#
# ## 1. 웹이란?
# -웹의 자원은 URL을 통해 요청
# ![URL%EC%9D%98%20%EA%B5%AC%EC%84%B1.png](attachment:URL%EC%9D%98%20%EA%B5%AC%EC%84%B1.png)
#
# ## 2. HTTP 요청 메소드
# ![HTTP_%EB%A9%94%EC%86%8C%EB%93%9C.png](attachment:HTTP_%EB%A9%94%EC%86%8C%EB%93%9C.png)
#
# ## 3. 크롤링 허용 여부 확인
# - 크롤링할 메인 페이지 주소/robots.txt!
# - User-agent:* : 모든 유저
# - Allow:/ : 허용하겟다.  , Disallow: / : 허용하지 않겟다
# - Allow : /달러 : 현재 파일 까지만 허용한다.
# ![%ED%81%AC%EB%A1%A4%EB%A7%81_%ED%97%88%EC%9A%A9%EC%97%AC%EB%B6%80.png](attachment:%ED%81%AC%EB%A1%A4%EB%A7%81_%ED%97%88%EC%9A%A9%EC%97%AC%EB%B6%80.png)
#
# ### 1) User-agent
# - 사용자 에이전트: 웹 브라우저나 애플리케이션이 웹 서버에 자신을 식별하기 위해 보내는 문자열로 브라우저 종류, 버젼, 운영체제 등의 정보를 포함
# - What is my user agent 검색하면 나의 사용자 에이전트를 알 수 있다.
# - Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36(내 에이전트)
#
# ## 2) HTML 태그
# - 태그를 기반으로 원하는 정보를 가져올 것이다.
# ![HTML_%ED%83%9C%EA%B7%B8.png](attachment:HTML_%ED%83%9C%EA%B7%B8.png)
#
# # 2. 크롤링 단계
#
# ## 1) URl 분석(네이버)
# https://ac.search.naver.com/nx/ac
# - 하나씩 분리 하며 어떤 역할인지 파악한다.
# - ?q=AI& 검색어
# - con=0&
# - frm=nv&
# - ans=2&
# - r_format=json&
# - r_enc=UTF-8&
# - r_unicode=0&
# - t_koreng=1&
# - run=2&
# - rev=4&
# - q_enc=UTF-8&
# - st=100&
# - _callback=_jsonp_5
#
# ## 2) 크롤링 허용 여부 확인
#
# ## 3) HTML 요청
#
# ## 4) 파씽
#
# ## 5) 데이터 정제 후 저장
